# %%
import pandas as pd

# %%
l1 = [1,2,3]
l2 = ['a','b','c']

df = pd.DataFrame(data=[l1,l2])

# %%
print(df.to_csv())
# Out:
# ,0,1,2
# 0,1,2,3
# 1,a,b,c

# %%
print(df.to_json())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-cd71d60c59d4> in <module>
# ----> 1 dict(df.to_json())
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required
